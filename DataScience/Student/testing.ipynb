# %%
## import df and see head
import pandas as pd
df = pd.read_csv("/Users/reubenjarvela/Desktop/General/GH_LearningPortfolio/DataScience/student_habits_performance.csv")

df.head(10)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
# 5      S1005   24    Male                  7.2                 1.3
# 6      S1006   21  Female                  5.6                 1.5
# 7      S1007   21  Female                  4.3                 1.0
# 8      S1008   23  Female                  4.4                 2.2
# 9      S1009   18  Female                  4.8                 3.1
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# ...

# %%
## get number of rows and columns
df.shape
# Out:
# (1000, 16)

# %%
## get name of columns
df.columns
# testing
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %%
## get column types
df.dtypes
# Out:
# student_id                        object
# age                                int64
# gender                            object
# study_hours_per_day              float64
# social_media_hours               float64
# netflix_hours                    float64
# part_time_job                     object
# attendance_percentage            float64
# sleep_hours                      float64
# diet_quality                      object
# exercise_frequency                 int64
# parental_education_level          object
# internet_quality                  object
# mental_health_rating               int64
# extracurricular_participation     object
# exam_score                       float64
# dtype: object

# %%
## return number of null values per column
df.isnull().sum()
# Out:
# student_id                        0
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
## return single column parental_education_level
df['parental_education_level']
# Out:
# 0           Master
# 1      High School
# 2      High School
# 3           Master
# 4           Master
#           ...
# 995    High School
# 996    High School
# 997       Bachelor
# 998       Bachelor
# 999       Bachelor
# Name: parental_education_level, Length: 1000, dtype: object

# %%
## create new df where parental_education_level is null and show first 5 values
null_edu = df[df['parental_education_level'].isnull()]
null_edu.head()
# Out:
#    student_id  age  gender  study_hours_per_day  social_media_hours  \
# 10      S1010   19  Female                  4.6                 3.7
# 33      S1033   18  Female                  4.0                 0.9
# 47      S1047   23  Female                  2.5                 2.9
# 74      S1074   21  Female                  2.3                 1.0
# 93      S1093   22    Male                  4.1                 2.5
#
#     netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 10            0.8            No                   77.6          5.8
# 33            1.1            No                   99.5          5.8
# 47            2.7            No                   83.5          7.0
# 74            0.4            No                  100.0          6.4
# 93            3.0            No                   85.1          5.8
#
#    diet_quality  exercise_frequency parental_education_level internet_quality  \
# ...

# %%
## show whole df of new df
null_edu
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 10       S1010   19  Female                  4.6                 3.7
# 33       S1033   18  Female                  4.0                 0.9
# 47       S1047   23  Female                  2.5                 2.9
# 74       S1074   21  Female                  2.3                 1.0
# 93       S1093   22    Male                  4.1                 2.5
# ..         ...  ...     ...                  ...                 ...
# 921      S1921   23  Female                  4.4                 2.7
# 925      S1925   19   Other                  1.7                 2.9
# 939      S1939   18  Female                  4.7                 3.2
# 945      S1945   23    Male                  6.0                 2.9
# 967      S1967   22    Male                  5.2                 4.1
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
## return rows where exam_score greater than 80
df[df['exam_score'] > 80]
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 1        S1001   20  Female                  6.9                 2.8
# 5        S1005   24    Male                  7.2                 1.3
# 6        S1006   21  Female                  5.6                 1.5
# 9        S1009   18  Female                  4.8                 3.1
# 21       S1021   21    Male                  5.6                 2.1
# ..         ...  ...     ...                  ...                 ...
# 980      S1980   20  Female                  3.7                 3.5
# 982      S1982   20  Female                  3.8                 2.4
# 984      S1984   24    Male                  3.2                 3.0
# 985      S1985   18    Male                  5.7                 3.1
# 991      S1991   20    Male                  6.0                 2.1
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
df['nerd'] = df['exam_score'] >= 85

# %%
df['nerd']
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: nerd, Length: 1000, dtype: bool

# %%
df[~df['nerd']]
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# 7        S1007   21  Female                  4.3                 1.0
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
df[(df['internet_quality'] == "Good") & (df['nerd'])]
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 9        S1009   18  Female                  4.8                 3.1
# 55       S1055   20    Male                  5.4                 2.8
# 62       S1062   21    Male                  4.5                 3.4
# 75       S1075   18  Female                  6.0                 3.4
# 96       S1096   18  Female                  6.0                 3.6
# ..         ...  ...     ...                  ...                 ...
# 908      S1908   23  Female                  5.6                 2.8
# 930      S1930   23    Male                  4.0                 0.3
# 972      S1972   17  Female                  4.5                 0.4
# 982      S1982   20  Female                  3.8                 2.4
# 991      S1991   20    Male                  6.0                 2.1
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
## return columns netflix_hours and gender where internet_quality is Good and nerd is true
df[(df['internet_quality'] == "Good") & (df['nerd'])][['netflix_hours', 'gender']]
# Out:
#      netflix_hours  gender
# 9              1.3  Female
# 55             3.8    Male
# 62             3.3    Male
# 75             2.0  Female
# 96             0.8  Female
# ..             ...     ...
# 908            0.5  Female
# 930            0.6    Male
# 972            3.0  Female
# 982            2.2  Female
# 991            3.0    Male
#
# [70 rows x 2 columns]

# %%
df.to_csv('student_habits_cleaned.csv', index = False)

# %%
import seaborn as sns
sns.boxplot(x='gender', y='exam_score', data=df)
# Out:
# <Axes: xlabel='gender', ylabel='exam_score'>

# %%
sns.scatterplot(x='study_hours_per_day', y='age', data=df)
# Out:
# <Axes: xlabel='study_hours_per_day', ylabel='age'>

# %%
import plotly.express as px
px.histogram(df, x='exam_score', y='gender')
